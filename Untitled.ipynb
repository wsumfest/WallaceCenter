# %%
import sys
import os
from os.path import join, dirname
from dotenv import load_dotenv
from apiclient.discovery import build
from apiclient.errors import HttpError

import numpy as np
import matplotlib.pyplot as plt

# %%
trends_server = "https://www.googleapis.com"
trends_version = "v1beta"
discovery_url = trends_server + '/discovery/v1/apis/trends/' + trends_version + '/rest'
trends_developer_key = "AIzaSyCx0zXMitbx15QlsZkoQPfYhEmAae-C4R4"
service = build('trends', trends_version, developerKey=trends_developer_key, discoveryServiceUrl=discovery_url)

# %%
CAterms = ["birth control", "contraception", "emergency contraception", "planned parenthood", "planned parenthood hours", "planned parenthood sacramento", "birth control pills", "birth control shot", "metedos anticonceptivos", "birth control options", "male birth control", "birth control implant", "birth control methods"]
TXterms = ["birth control", "birth control patch", "birth control shot", "contraception", "birth control pills", "birth control options", "birth control implant", "male birth control", "iud birth control"]
USterms = ['birth control', "birth control implant", "birth control pills", "iud", "mirena iud", "mirena iud reviews", "mirena side effects", "copper iud", "copper iud reviews", "iud insertion", "iud insertion pain", "skyla iud", "iud birth control", "contraception", "emergency contraception", "contraception defenition", "what is contraception", "define contraception", "birth control shot", "depo shot", "depo provera shot", "depo shot symptoms", "depo shot calendar", "birth control options", "male birth control", "planned parenthood", "planned parenthood hours", "planned parenthood nyc", "yaz birth control"]
ORterms = ["birth control", "contraception", "birth control options", "planned parenthood", "planned parenthood portland", "planned parenthood eugene", "metedos anticonceptivos", "male birth control", "birth control implant"]
#trendsValues = service.getTimelinesForHealth(terms=USterms, geoRestriction_country="US", time_startDate="2016-01-01").execute()
#CAtrendsValues = service.getTimelinesForHealth(terms=USterms, geoRestriction_region="US-CA", time_startDate="2016-01-01").execute()
#TXtrendsValues = service.getTimelinesForHealth(terms=USterms, geoRestriction_region="US-TX", time_startDate="2016-01-01").execute()
#ORtrendsValues = service.getTimelinesForHealth(terms=ORterms, geoRestriction_region="US-OR", time_startDate="2015-04-05", time_endDate="2016-04-05").execute()
#ORtrendsValues1 = service.getTimelinesForHealth(terms=ORterms, geoRestriction_region="US-OR", time_startDate="2014-04-05", time_endDate="2015-04-05").execute()

CAtrendsValues1 = service.getTimelinesForHealth(terms=CAterms, geoRestriction_region="US-CA", time_startDate="2015-04-05", time_endDate="2016-04-05").execute()
CAtrendsValues2 = service.getTimelinesForHealth(terms=CAterms, geoRestriction_region="US-CA", time_startDate="2014-04-05", time_endDate="2015-04-05").execute()

ORw = service.getTimelinesForHealth(terms=ORterms, geoRestriction_region="US-OR", time_startDate="2014-04-05", time_endDate="2015-04-05").execute()
ORy = service.getTimelinesForHealth(terms=ORterms, geoRestriction_region="US-OR", time_startDate="2014-04-05", time_endDate="2015-04-05", timelineResolution='year').execute()
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-122-1babefb2476e> in <module>()
#       9 #ORtrendsValues1 = service.getTimelinesForHealth(terms=ORterms, geoRestriction_region="US-OR", time_startDate="2014-04-05", time_endDate="2015-04-05").execute()
#      10
# ---> 11 CAtrendsValues1 = service.getTimelinesForHealth(terms=CAterms, geoRestriction_region="US-CA", time_startDate="2015-04-05", time_endDate="2016-04-05").execute()
#      12 CAtrendsValues2 = service.getTimelinesForHealth(terms=CAterms, geoRestriction_region="US-CA", time_startDate="2014-04-05", time_endDate="2015-04-05").execute()
#      13
#
# /Library/Python/2.7/site-packages/oauth2client/util.pyc in positional_wrapper(*args, **kwargs)
#     133                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     134                     logger.warning(message)
# ...

# %%
def stripValues(values):
    stripped = values["lines"]
    retVal = dict()
    for item in stripped:
        term = item["term"]
        points = item["points"]
        total, summ = 0,0
        for point in points:
            total += 1
            summ += point["value"]
        retVal[term] = summ*7
    return retVal

# %%
newDict = stripValues(trendsValues)
CAnewDict = stripValues(CAtrendsValues)
TXnewDict = stripValues(TXtrendsValues)
ORdict = stripValues(ORtrendsValues)
ORdict1 = stripValues(ORtrendsValues1)

CAnewDict1 = stripValues(CAtrendsValues1)
CAnewDict2 = stripValues(CAtrendsValues2)

# %%
words = newDict.keys()
values = newDict.values()
CAvalues = CAnewDict.values()
TXvalues = TXnewDict.values()
width = .25
fig, ax = plt.subplots()
ind = np.arange(len(words))
rects1 = ax.bar(ind, values, width, color='r')
rects2 = ax.bar(ind+width, CAvalues, width, color='b')
rects3 = ax.bar(ind+width*2, TXvalues, width, color='g')
ax.set_xticks(ind+width)
ax.set_ylabel('Volume of Searches')
ax.set_title('Most Common Searched Queries Related to Birth Control\n Between 01/01/16-04/15/17')
ax.set_xticklabels(words, rotation='vertical')
ax.legend((rects1[0], rects2[0], rects3[0]), ("United States", "California", "Texas"))

plt.show()

# %%
words = ORdict.keys()
values = ORdict.values()
width = .5
fig, ax = plt.subplots()
ind = np.arange(len(words))
rects1 = ax.bar(ind, values, width, color='r')

ax.set_xticks(ind)
ax.set_ylabel('Volume of Searches')
ax.set_title('Most Common Searched Queries Related to Birth Control\n Between 04/05/15-04/05/16')
ax.set_xticklabels(words, rotation='vertical')

plt.show()

# %%
words = ORdict1.keys()
values = ORdict1.values()
width = .5
fig, ax = plt.subplots()
ind = np.arange(len(words))
rects1 = ax.bar(ind, values, width, color='r')

ax.set_xticks(ind)
ax.set_ylabel('Volume of Searches')
ax.set_title('Most Common Searched Queries Related to Birth Control\n Between 04/05/14-04/05/15')
ax.set_xticklabels(words, rotation='vertical')

plt.show()

# %%
words = ORdict.keys()
words1 = ORdict1.keys()
values = ORdict.values()
values1 = ORdict1.values()
width = .33
fig, ax = plt.subplots()
ind = np.arange(len(words))
rects1 = ax.bar(ind, values, width, color='r')
rects2 = ax.bar(ind+width, values1, width, color='b')

percentChangeBC = ((ORdict["birth control"] - ORdict1["birth control"])/ORdict1["birth control"])*100
print percentChangeBC

percentChangePP = ((ORdict["planned parenthood"] - ORdict1["planned parenthood"])/ORdict1["planned parenthood"])*100
print percentChangePP

ax.set_xticks(ind+width)
ax.set_ylabel('Volume of Searches')
ax.set_title('Most Common Searched Queries Related to Birth Control\n in Oregon')
ax.set_xticklabels(words, rotation='vertical')
ax.legend((rects1[0], rects2[0]), ("04/05/2015-04/05/2016", "04/05/2014-04/05/2015"))

plt.show()
# Out:
# 14.7567921614
# 61.4070581168

# %%
words = CAnewDict1.keys()
words1 = CAnewDict2.keys()
values = CAnewDict1.values()
values1 = CAnewDict2.values()
width = .33
fig, ax = plt.subplots()
ind = np.arange(len(words))
rects1 = ax.bar(ind, values, width, color='r')
rects2 = ax.bar(ind+width, values1, width, color='b')

percentChangeBC = ((CAnewDict1["birth control"] - CAnewDict2["birth control"])/CAnewDict2["birth control"])*100


percentChangePP = ((CAnewDict1["planned parenthood"] - CAnewDict2["planned parenthood"])/CAnewDict2["planned parenthood"])*100


ax.set_xticks(ind+width)
ax.set_ylabel('Volume of Searches')
ax.set_title('Most Common Searched Queries Related to Birth Control\n in California')
ax.set_xticklabels(words, rotation='vertical')
ax.legend((rects1[0], rects2[0]), ("04/05/2015-04/05/2016", "04/05/2014-04/05/2015"))

plt.show()
# Out:
# 1.75817464699
# 33.8788438837
